# %% [markdown]
# <a href="https://colab.research.google.com/github/italosciaraffia/Repo_Proyecto_Equipo-Fernandez-Merino/blob/main/Entrega3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install altair

# %%
import pandas as pd
import altair as alt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-85114442-89da-485d-8316-1f3a678c6819" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85114442-89da-485d-8316-1f3a678c6819">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('01_conteo_simple.xlsx')

# %%
df.columns
# Out:
# Index(['SEXO', 'GRUPO_EDAD', 'CONDICION_EGRESO', 'GLOSA_PAIS_ORIGEN',
#        'GLOSA_REGION_RESIDENCIA', 'ANO_EGRESO', 'COUNT'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# %%
source = df_grouped.copy()

# %%
base = alt.Chart(source).encode(
    theta=alt.Theta("PORCENTAJE:Q").stack(True),
    radius=alt.Radius("PORCENTAJE", scale=alt.Scale(type="sqrt", zero=True, rangeMin=20)),
    color=alt.Color("GRUPO_EDAD:N", legend=alt.Legend(title="Grupo Etario"))
)

# %%
c1 = base.mark_arc(innerRadius=50, stroke="#fff")

# %%
c2 = base.mark_text(radiusOffset=15).encode(
    text=alt.Text("PORCENTAJE:Q", format=".1f")
)

# %%
(c1 + c2).properties(
    title="Edad y hospitalización: Análisis etario de la ocupación hospitalaria",
    width=800,    # ancho en píxeles
    height=600    # alto en píxeles
).configure_title(
    fontSize=20,
    anchor='middle'
)
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
import altair as alt

# 1. Leer el archivo y preparar los datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()

# 2. Seleccionar y agrupar datos
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

# 3. Crear gráfico Altair tipo donut con tamaño grande y título
base = alt.Chart(df_grouped).encode(
    alt.Theta("COUNT:Q", stack=True),
    alt.Color("GRUPO_EDAD:N", legend=alt.Legend(title="Grupo Etario"))
)

pie = base.mark_arc(outerRadius=120)
text = base.mark_text(radius=140, size=20).encode(text="GRUPO_EDAD:N")

chart = (pie + text).properties(
    width=600,
    height=600,
    title="Edad y hospitalización: Análisis etario de la ocupación hospitalaria"
).configure_title(
    fontSize=24,
    anchor='middle'
)

chart
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
import altair as alt

# 1. Leer el archivo y preparar los datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()

# 2. Seleccionar y agrupar datos
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

# 3. Calcular porcentaje
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# 4. Crear gráfico Altair tipo donut con porcentaje en etiquetas
base = alt.Chart(df_grouped).encode(
    alt.Theta("COUNT:Q", stack=True),
    alt.Color("GRUPO_EDAD:N", legend=alt.Legend(title="Grupo Etario"))
)

pie = base.mark_arc(outerRadius=120)

# Etiquetas con porcentaje formateado a 1 decimal
text = base.mark_text(radius=140, size=20).encode(
    text=alt.Text('PORCENTAJE:Q', format='.1f')
)

chart = (pie + text).properties(
    width=600,
    height=600,
    title="Edad y hospitalización: Análisis etario de la ocupación hospitalaria"
).configure_title(
    fontSize=24,
    anchor='middle'
)
chart
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
import altair as alt

# Carga y prepara los datos (igual que antes)
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "menor de un año",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje (%)'),
    y=alt.value(50),  # Altura fija para que sea una barra horizontal
    color=alt.Color(
        'GRUPO_EDAD:N',
        legend=alt.Legend(title='Grupo Etario'),
        sort=orden  # Aquí aplicamos el orden personalizado
    ),
    tooltip=[alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
             alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')]
).properties(
    width=600,
    height=100,
    title='Distribución porcentual apilada por grupo etario'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "menor de un año",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Forzar orden categórico
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje (%)'),
    y=alt.value(50),  # Altura fija para barra única horizontal
    color=alt.Color(
        'GRUPO_EDAD:N',
        legend=alt.Legend(title='Grupo Etario'),
        sort=orden
    ),
    tooltip=[alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
             alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')]
).properties(
    width=600,
    height=100,
    title='Distribución porcentual apilada por grupo etario'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# Orden deseado
orden = [
    "menor de un año",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Forzar orden categórico
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico
chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('PORCENTAJE:Q', stack='zero', title='Porcentaje (%)'),
    y=alt.Y('GRUPO_EDAD:N', sort=orden, axis=None),  # eje Y fijo a ordenar los segmentos
    color=alt.Color(
        'GRUPO_EDAD:N',
        sort=orden,
        legend=alt.Legend(title='Grupo Etario')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')
    ]
).properties(
    width=600,
    height=100,
    title='Distribución porcentual apilada por grupo etario'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Cargar y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

# Calcular porcentaje
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# Definir orden deseado
orden = [
    "menor de un año",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Aplicar tipo categórico ordenado
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico
chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('PORCENTAJE:Q', stack='zero', title='Porcentaje (%)'),
    y=alt.Y('dummy:N', title=None),  # Eje Y fijo
    color=alt.Color('GRUPO_EDAD:N', sort=orden, legend=alt.Legend(title='Grupo Etario')),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')
    ]
).transform_calculate(
    dummy='"Distribución"'  # valor constante para una sola barra
).properties(
    width=600,
    height=100,
    title='Distribución porcentual apilada por grupo etario'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()

total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# Define orden deseado
orden = [
    "menor de un año",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Convertir a categoría ordenada para controlar el orden de apilamiento
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico
chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje (%)'),
    y=alt.value(50),  # barra horizontal única
    color=alt.Color('GRUPO_EDAD:N', legend=alt.Legend(title='Grupo Etario')),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')
    ]
).properties(
    width=600,
    height=100,
    title='Distribución porcentual apilada por grupo etario'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()

# Reemplazar nombre
df['GRUPO_EDAD'] = df['GRUPO_EDAD'].replace({'menor de un año': '0 a 1'})

# Agrupar y calcular porcentaje
df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

# Orden actualizado
orden = [
    "0 a 1",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Categoría ordenada
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Gráfico
chart = alt.Chart(df_grouped).mark_bar().encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje (%)'),
    y=alt.value(50),
    color=alt.Color('GRUPO_EDAD:N', legend=alt.Legend(title='Grupo Etario')),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('PORCENTAJE:Q', format='.1f', title='Porcentaje (%)')
    ]
).properties(
    width=800,
    height=100,
    title='Edad y hospitalización: Análisis etario de la ocupación hospitalaria'
).configure_title(
    fontSize=20,
    anchor='middle'
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df['GRUPO_EDAD'] = df['GRUPO_EDAD'].replace({'menor de un año': '0 a 1'})

df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "0 a 1",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Ordenar categorías
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico embellecido
chart = alt.Chart(df_grouped).mark_bar(size=50).encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje de hospitalización (%)'),
    y=alt.value(80),
    color=alt.Color('GRUPO_EDAD:N',
        scale=alt.Scale(scheme='category20b'),
        legend=alt.Legend(title='Grupo Etario', orient='bottom')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('COUNT:Q', title='Cantidad'),
        alt.Tooltip('PORCENTAJE:Q', format='.2f', title='% del total')
    ]
).properties(
    width=800,
    height=120,
    title=alt.TitleParams(
        text='Edad y hospitalización: Análisis etario de la ocupación hospitalaria',
        fontSize=22,
        anchor='middle',
        font='Helvetica Neue'
    )
).configure_axis(
    grid=False,
    labelFontSize=12,
    titleFontSize=14
).configure_view(
    stroke=None  # quita el borde gris del gráfico
).configure_legend(
    titleFontSize=14,
    labelFontSize=12,
    orient='bottom',
    columns=3
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df['GRUPO_EDAD'] = df['GRUPO_EDAD'].replace({'menor de un año': '0 a 1'})

df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "0 a 1",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Ordenar categorías
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico con esquema azul
chart = alt.Chart(df_grouped).mark_bar(size=50).encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje de hospitalización (%)'),
    y=alt.value(80),
    color=alt.Color('GRUPO_EDAD:N',
        scale=alt.Scale(scheme='blues'),
        legend=alt.Legend(title='Grupo Etario', orient='bottom')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('COUNT:Q', title='Cantidad'),
        alt.Tooltip('PORCENTAJE:Q', format='.2f', title='% del total')
    ]
).properties(
    width=800,
    height=120,
    title=alt.TitleParams(
        text='Edad y hospitalización: Análisis etario de la ocupación hospitalaria',
        fontSize=22,
        anchor='middle',
        font='Helvetica Neue'
    )
).configure_axis(
    grid=False,
    labelFontSize=12,
    titleFontSize=14
).configure_view(
    stroke=None
).configure_legend(
    titleFontSize=14,
    labelFontSize=14,
    orient='bottom',
    columns=11
)

chart
# Out:
# alt.Chart(...)

# %%
import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df['GRUPO_EDAD'] = df['GRUPO_EDAD'].replace({'menor de un año': '0 a 1'})

df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "0 a 1",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Ordenar categorías
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico con esquema azul
chart = alt.Chart(df_grouped).mark_bar(size=50).encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje de hospitalización (%)'),
    y=alt.value(80),
    color=alt.Color('GRUPO_EDAD:N',
        scale=alt.Scale(scheme='blues'),
        legend=alt.Legend(title='Grupo Etario', orient='bottom')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('COUNT:Q', title='Cantidad'),
        alt.Tooltip('PORCENTAJE:Q', format='.2f', title='% del total')
    ]
).properties(
    width=800,
    height=120,
    title=alt.TitleParams(
        text='Edad y hospitalización: Análisis etario de la ocupación hospitalaria',
        fontSize=22,
        anchor='middle',
        font='Helvetica Neue'
    )
).configure_axis(
    grid=False,
    labelFontSize=12,
    titleFontSize=14
).configure_view(
    stroke=None
).configure_legend(
    titleFontSize=14,
    labelFontSize=14,
    orient='bottom',
    columns=11
)

import pandas as pd
import altair as alt

# Leer y preparar datos
df = pd.read_excel('01_conteo_simple.xlsx')
df.columns = df.columns.str.strip().str.upper()
df['GRUPO_EDAD'] = df['GRUPO_EDAD'].replace({'menor de un año': '0 a 1'})

df = df[['GRUPO_EDAD', 'COUNT']]
df_grouped = df.groupby('GRUPO_EDAD', as_index=False)['COUNT'].sum()
total = df_grouped['COUNT'].sum()
df_grouped['PORCENTAJE'] = (df_grouped['COUNT'] / total) * 100

orden = [
    "0 a 1",
    "1 a 9",
    "10 a 19",
    "20 a 29",
    "30 a 39",
    "40 a 49",
    "50 a 59",
    "60 a 69",
    "70 a 79",
    "80 a 89",
    "90 y más",
]

# Ordenar categorías
cat_type = pd.CategoricalDtype(categories=orden, ordered=True)
df_grouped['GRUPO_EDAD'] = df_grouped['GRUPO_EDAD'].astype(cat_type)

# Crear gráfico con esquema azul
chart = alt.Chart(df_grouped).mark_bar(size=50).encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje de hospitalización (%)'),
    y=alt.value(80),
    color=alt.Color('GRUPO_EDAD:N',
        scale=alt.Scale(scheme='blues'),
        legend=alt.Legend(title='Grupo Etario', orient='bottom')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('COUNT:Q', title='Cantidad'),
        alt.Tooltip('PORCENTAJE:Q', format='.2f', title='% del total')
    ]
).properties(
    width=800,
    height=120,
    title=alt.TitleParams(
        text='Edad y hospitalización: Análisis etario de la ocupación hospitalaria',
        fontSize=22,
        anchor='middle',
        font='Helvetica Neue'
    )
).configure_axis(
    grid=False,
    labelFontSize=12,
    titleFontSize=14
).configure_view(
    stroke=None
).configure_legend(
    titleFontSize=14,
    labelFontSize=14,
    orient='bottom',
    columns=11
)

df_grouped = df_grouped.sort_values(by='GRUPO_EDAD')  # asegurar orden correcto
df_grouped['POS'] = df_grouped['PORCENTAJE'].cumsum() - df_grouped['PORCENTAJE'] / 2

bars = alt.Chart(df_grouped).mark_bar(size=50).encode(
    x=alt.X('sum(PORCENTAJE):Q', stack='zero', title='Porcentaje de hospitalización (%)'),
    y=alt.value(80),
    color=alt.Color('GRUPO_EDAD:N',
        scale=alt.Scale(scheme='blues'),
        legend=alt.Legend(title='Grupo Etario', orient='bottom')
    ),
    tooltip=[
        alt.Tooltip('GRUPO_EDAD:N', title='Grupo Etario'),
        alt.Tooltip('COUNT:Q', title='Cantidad'),
        alt.Tooltip('PORCENTAJE:Q', format='.2f', title='% del total')
    ]
)

# Etiquetas de texto con porcentaje
labels = alt.Chart(df_grouped).mark_text(
    dy=-15,  # desplazar hacia arriba de la barra
    fontSize=8,
    fontWeight='bold',
    color='black'
).encode(
    x=alt.X('POS:Q'),
    y=alt.value(80),
    text=alt.Text('PORCENTAJE:Q', format='.1f')
)

# Combinar barras y texto
chart = (bars + labels).properties(
    width=800,
    height=110,
    title=alt.TitleParams(
        text='Edad y hospitalización: Análisis etario de la ocupación hospitalaria',
        fontSize=22,
        anchor='middle',
        font='Helvetica Neue'
    )
).configure_view(
    stroke=None
).configure_axis(
    grid=False
).configure_legend(
    titleFontSize=14,
    labelFontSize=12,
    orient='bottom',
    columns=11
)

chart
# Out:
# alt.LayerChart(...)

# %%
chart.save('grafico.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-6938184ba01c> in <cell line: 0>()
# ----> 1 chart.save('grafico.png')
#
# /usr/local/lib/python3.11/dist-packages/altair/vegalite/v5/api.py in save(self, fp, format, override_data_transformer, scale_factor, mode, vegalite_version, vega_version, vegaembed_version, embed_options, json_kwds, engine, inline, **kwargs)
#    2287         if override_data_transformer:
#    2288             with data_transformers.disable_max_rows():
# -> 2289                 save(**kwds)
#    2290         else:
#    2291             save(**kwds)
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/save.py in save(chart, fp, vega_version, vegaembed_version, format, mode, vegalite_version, embed_options, json_kwds, scale_factor, engine, inline, **kwargs)
#     222         # described at https://github.com/vega/vl-convert/issues/31
# ...
